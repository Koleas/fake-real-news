# %%
import pandas as pd

# %%
df = pd.read_csv ('dataset/Fake.csv')
fileFake = df['text'].to_list()
bb={}

# %%
def updatedict(dictionary1,dictionary2):
    for i in dictionary2.keys():
        if i in dictionary1:
            dictionary1[i]+=dictionary2[i]
        else:
            dictionary1[i]=dictionary2[i]
    return dictionary1

# %%
for j in fileFake:
    a = list(map(lambda x: x.lower().replace(".","").replace(",","").replace(":","").replace("@",""),j.split(' ')))
    b={i:0 for i in a}
    for i in a:
        b[i]+=1
    bb=updatedict(bb,b)

# %%
blacklist = ['the','a']

# %%
for d in blacklist:
    del bb[d]

# %%
#Сортировка
bb={k: v for k, v in sorted(bb.items(), key=lambda item: item[1], reverse=True)}
bb
# Out:
# {'to': 289355,
#  '': 288427,
#  'of': 235555,
#  'and': 223310,
#  'in': 163918,
#  'that': 149254,
#  's': 129259,
#  'is': 110473,
#  'for': 91734,
#  'on': 80994,
#  'it': 77417,
#  'he': 77057,
#  'trump': 72637,
#  'was': 67629,
#  'with': 62735,
#  'his': 57940,
#  'as': 55526,
#  'this': 54349,
#  'be': 48453,
#  'by': 47270,
#  'are': 46178,
#  'have': 45963,
#  'they': 44903,
#  'not': 44634,
#  'i': 42774,
#  'has': 42219,
#  'who': 41912,
#  'at': 41311,
#  'from': 40529,
#  't': 40500,
#  'you': 39320,
#  'we': 37620,
#  'an': 34764,
#  'about': 32683,
#  'but': 31189,
#  'said': 30957,
#  'their': 30179,
#  'people': 25649,
#  'she': 25560,
#  'her': 25486,
#  'president': 25191,
#  'or': 24235,
#  'all': 24193,
#  'what': 24099,
#  'will': 24020,
#  'would': 23400,
#  'been': 22975,
#  'one': 22722,
#  'out': 22683,
#  'more': 22110,
#  'if': 21749,
#  'us': 21694,
#  'were': 21561,
#  'when': 21083,
#  'had': 20405,
#  'just': 20081,
#  'our': 19666,
#  'so': 18919,
#  'can': 18846,
#  'there': 18595,
#  'no': 17925,
#  'up': 17898,
#  'clinton': 17790,
#  'obama': 17588,
#  'like': 17465,
#  'which': 17147,
#  'donald': 17044,
#  'after': 16684,
#  'him': 16343,
#  'because': 15408,
#  'also': 15165,
#  'do': 15091,
#  'new': 14107,
#  'over': 13875,
#  'how': 13870,
#  'news': 13862,
#  'than': 13709,
#  'even': 13548,
#  'them': 13482,
#  'into': 13384,
#  'hillary': 13323,
#  'other': 13154,
#  'now': 12824,
#  'only': 12701,
#  'white': 12692,
#  'time': 12528,
#  'state': 12409,
#  'being': 12072,
#  'some': 11530,
#  'any': 11427,
#  'via': 11105,
#  'against': 11007,
#  're': 10946,
#  'media': 10863,
#  'should': 10837,
#  'get': 10668,
#  'these': 10665,
#  'campaign': 10451,
#  'house': 10440,
#  'america': 10262,
#  'could': 10182,
#  'know': 10179,
#  'first': 9931,
#  'don': 9893,
#  'american': 9892,
#  'going': 9701,
#  'many': 9649,
#  'its': 9620,
#  'while': 9594,
#  'then': 9495,
#  'states': 9345,
#  'most': 9337,
#  'image': 9223,
#  'very': 9175,
#  'make': 9117,
#  'did': 9096,
#  'told': 9095,
#  'republican': 8935,
#  'my': 8922,
#  'those': 8888,
#  'your': 8778,
#  'during': 8740,
#  'made': 8651,
#  'before': 8593,
#  'police': 8482,
#  'government': 8478,
#  'country': 8455,
#  'say': 8431,
#  'way': 8327,
#  'back': 8273,
#  'two': 8258,
#  'think': 8228,
#  'here': 8181,
#  'right': 8152,
#  'years': 8073,
#  'where': 7983,
#  'united': 7954,
#  'election': 7824,
#  'last': 7784,
#  'video': 7713,
#  'may': 7599,
#  'political': 7530,
#  'down': 7498,
#  'black': 7396,
#  'party': 7355,
#  'want': 7255,
#  'national': 7039,
#  'women': 7033,
#  'former': 7026,
#  'republicans': 6979,
#  'why': 6947,
#  'says': 6919,
#  'me': 6857,
#  'much': 6853,
#  'well': 6846,
#  'world': 6841,
#  'law': 6759,
#  'take': 6675,
#  'see': 6506,
#  'go': 6486,
#  'public': 6471,
#  'year': 6420,
#  'own': 6260,
#  'man': 6251,
#  'never': 6171,
#  'according': 6163,
#  'another': 6143,
#  'bill': 6098,
#  'americans': 6018,
#  'every': 6002,
#  'really': 5976,
#  'fact': 5974,
#  'day': 5961,
#  'since': 5956,
#  'support': 5796,
#  'show': 5792,
#  'still': 5708,
#  'under': 5691,
#  'presidential': 5674,
#  'fbi': 5597,
#  'security': 5551,
#  'didn': 5542,
#  'called': 5534,
#  'off': 5532,
#  'story': 5459,
#  'such': 5458,
#  'group': 5451,
#  'washington': 5437,
#  've': 5417,
#  'administration': 5410,
#  'department': 5385,
#  'vote': 5347,
#  'same': 5315,
#  'federal': 5298,
#  'through': 5274,
#  'good': 5237,
#  'm': 5213,
#  'office': 5206,
#  'doesn': 5189,
#  'does': 5183,
#  'russia': 5160,
#  'fox': 5090,
#  'saying': 5044,
#  'court': 5027,
#  'need': 5021,
#  'work': 4980,
#  'come': 4977,
#  'asked': 4965,
#  'times': 4923,
#  'actually': 4921,
#  '2016': 4869,
#  'something': 4845,
#  'left': 4837,
#  'million': 4793,
#  'between': 4790,
#  'got': 4788,
#  'part': 4767,
#  'democratic': 4752,
#  'both': 4684,
#  'around': 4590,
#  'used': 4554,
#  'took': 4547,
#  'week': 4545,
#  'family': 4542,
#  'money': 4523,
#  'case': 4519,
#  'things': 4502,
#  'went': 4478,
#  'twitter': 4468,
#  'war': 4447,
#  'again': 4423,
#  'press': 4400,
#  'report': 4399,
#  'put': 4384,
#  'thing': 4317,
#  'including': 4314,
#  'york': 4283,
#  'believe': 4282,
#  'use': 4275,
#  'today': 4274,
#  'images': 4236,
#  'help': 4233,
#  'democrats': 4231,
#  'let': 4215,
#  'russian': 4204,
#  'post': 4196,
#  'city': 4192,
#  'candidate': 4190,
#  'too': 4178,
#  'cnn': 4156,
#  'gop': 4134,
#  'percent': 4115,
#  'great': 4096,
#  'information': 4093,
#  'nothing': 4082,
#  'look': 4038,
#  'attack': 4036,
#  'ever': 4023,
#  'matter': 3980,
#  'woman': 3953,
#  'interview': 3929,
#  'nation': 3885,
#  'order': 3864,
#  'long': 3851,
#  'doing': 3840,
#  'without': 3832,
#  'john': 3830,
#  'statement': 3828,
#  'investigation': 3817,
#  'children': 3799,
#  'though': 3790,
#  'himself': 3779,
#  'school': 3779,
#  'speech': 3755,
#  'rights': 3747,
#  'point': 3730,
#  'officials': 3727,
#  'justice': 3723,
#  'however': 3719,
#  'real': 3696,
#  'anyone': 3694,
#  'person': 3690,
#  'won': 3684,
#  'already': 3680,
#  'watch': 3679,
#  'course': 3665,
#  'gun': 3658,
#  'far': 3640,
#  'trying': 3633,
#  'supporters': 3624,
#  'three': 3618,
#  'might': 3603,
#  'policy': 3595,
#  'little': 3581,
#  'general': 3579,
#  'mr': 3577,
#  'military': 3567,
#  'secretary': 3560,
#  'll': 3549,
#  'place': 3525,
#  'intelligence': 3518,
#  'congress': 3503,
#  'members': 3503,
#  'came': 3501,
#  'found': 3493,
#  'muslim': 3478,
#  'change': 3474,
#  'senate': 3473,
#  'social': 3468,
#  'january': 3462,
#  'away': 3460,
#  'call': 3446,
#  '&': 3436,
#  'reported': 3434,
#  'stop': 3433,
#  'end': 3427,
#  'anything': 3425,
#  'isn': 3410,
#  'care': 3404,
#  'sanders': 3403,
#  'yet': 3382,
#  'night': 3373,
#  'someone': 3356,
#  'cruz': 3355,
#  'making': 3351,
#  'keep': 3340,
#  'clear': 3339,
#  'history': 3339,
#  'lives': 3329,
#  'become': 3326,
#  'foreign': 3306,
#  'life': 3304,
#  'voters': 3303,
#  'big': 3297,
#  'next': 3277,
#  'few': 3256,
#  'community': 3245,
#  'act': 3244,
#  'home': 3228,
#  'march': 3228,
#  'men': 3225,
#  'whether': 3215,
#  'lot': 3202,
#  'least': 3201,
#  'business': 3194,
#  'number': 3193,
#  'free': 3182,
#  'question': 3165,
#  'give': 3164,
#  'enough': 3155,
#  'd': 3153,
#  'director': 3128,
#  'better': 3117,
#  'illegal': 3104,
#  'conservative': 3084,
#  'done': 3080,
#  'days': 3078,
#  'power': 3071,
#  'several': 3069,
#  'sure': 3060,
#  'must': 3060,
#  'once': 3056,
#  'seen': 3023,
#  'evidence': 3010,
#  'racist': 3002,
#  'having': 3000,
#  'immigration': 2979,
#  'violence': 2961,
#  'likely': 2953,
#  'working': 2950,
#  'health': 2941,
#  'senator': 2933,
#  'students': 2905,
#  'everyone': 2895,
#  'july': 2883,
#  'fake': 2879,
#  'instead': 2870,
#  'job': 2860,
#  'recent': 2860,
#  'best': 2858,
#  'daily': 2824,
#  'tell': 2822,
#  'committee': 2810,
#  'taking': 2804,
#  'getting': 2802,
#  'released': 2801,
#  'deal': 2794,
#  'live': 2792,
#  'november': 2778,
#  'syria': 2777,
#  'past': 2770,
#  'comes': 2749,
#  'member': 2743,
#  'reports': 2741,
#  'facebook': 2741,
#  'later': 2734,
#  'win': 2727,
#  'am': 2726,
#  'read': 2725,
#  'death': 2725,
#  'top': 2713,
#  'given': 2708,
#  'find': 2707,
#  'across': 2703,
#  'using': 2685,
#  'words': 2685,
#  'pay': 2683,
#  'hate': 2678,
#  'j': 2670,
#  'barack': 2667,
#  'system': 2664,
#  'wrote': 2660,
#  'months': 2659,
#  'entire': 2657,
#  'email': 2655,
#  'young': 2651,
#  'official': 2644,
#  'program': 2633,
#  'attorney': 2626,
#  'decision': 2607,
#  'able': 2606,
#  'bad': 2605,
#  'known': 2605,
#  'team': 2598,
#  'century': 2597,
#  'following': 2595,
#  'until': 2592,
#  'june': 2591,
#  'reason': 2576,
#  'university': 2576,
#  'wall': 2572,
#  'wasn': 2560,
#  'issue': 2558,
#  'seems': 2557,
#  'claims': 2555,
#  'north': 2554,
#  'democrat': 2551,
#  'taken': 2542,
#  'tax': 2535,
#  'continue': 2533,
#  'meeting': 2522,
#  'wants': 2521,
#  'talk': 2520,
#  'shooting': 2514,
#  'officers': 2513,
#  'behind': 2503,
#  'others': 2487,
#  'hard': 2486,
#  'february': 2481,
#  'name': 2478,
#  'full': 2470,
#  'problem': 2459,
#  'happened': 2454,
#  'high': 2451,
#  'along': 2449,
#  'important': 2448,
#  'calling': 2442,
#  'control': 2441,
#  'special': 2428,
#  'event': 2424,
#  'response': 2417,
#  'december': 2415,
#  'talking': 2405,
#  'stand': 2402,
#  'groups': 2395,
#  'company': 2388,
#  'october': 2384,
#  'coming': 2379,
#  'major': 2379,
#  'makes': 2377,
#  'nominee': 2375,
#  'face': 2371,
#  'thought': 2365,
#  'host': 2361,
#  'judge': 2354,
#  'among': 2350,
#  'liberal': 2333,
#  'comey': 2331,
#  'legal': 2330,
#  'four': 2328,
#  'set': 2319,
#  'tuesday': 2319,
#  'run': 2315,
#  'morning': 2307,
#  'leader': 2306,
#  'true': 2304,
#  'plan': 2300,
#  'wire': 2294,
#  'everything': 2290,
#  'friday': 2287,
#  'running': 2279,
#  '21st': 2274,
#  'decided': 2255,
#  'second': 2253,
#  'ago': 2250,
#  'room': 2248,
#  'less': 2244,
#  'local': 2242,
#  'shot': 2242,
#  'kind': 2239,
#  'means': 2239,
#  'always': 2238,
#  'private': 2236,
#  'recently': 2228,
#  'clearly': 2227,
#  'idea': 2223,
#  'love': 2220,
#  'truth': 2214,
#  'human': 2207,
#  'sexual': 2207,
#  'action': 2206,
#  'race': 2201,
#  'open': 2188,
#  'different': 2187,
#  'ryan': 2185,
#  'pretty': 2184,
#  'line': 2179,
#  'tried': 2175,
#  'service': 2175,
#  'attacks': 2172,
#  'emails': 2171,
#  'began': 2152,
#  'april': 2151,
#  'claim': 2151,
#  'september': 2148,
#  'street': 2143,
#  'shows': 2135,
#  'gave': 2135,
#  'rather': 2134,
#  'old': 2132,
#  'guy': 2131,
#  'muslims': 2131,
#  'fight': 2130,
#  'monday': 2129,
#  'criminal': 2129,
#  'source': 2129,
#  'county': 2123,
#  'debate': 2122,
#  'almost': 2120,
#  'themselves': 2120,
#  'despite': 2112,
#  'needs': 2110,
#  'international': 2100,
#  'move': 2096,
#  'each': 2096,
#  'claimed': 2093,
#  'message': 2088,
#  'probably': 2087,
#  '2017': 2086,
#  'head': 2071,
#  'force': 2069,
#  'within': 2061,
#  'august': 2061,
#  'countries': 2059,
#  'citizens': 2055,
#  'paul': 2051,
#  'executive': 2050,
#  'border': 2047,
#  'lost': 2046,
#  'comments': 2041,
#  'wanted': 2041,
#  'simply': 2040,
#  'texas': 2030,
#  'rally': 2028,
#  'thursday': 2023,
#  'wrong': 2022,
#  'sunday': 2021,
#  'killed': 2020,
#  'bush': 2020,
#  'tweet': 2019,
#  'officer': 2017,
#  '2015': 2015,
#  'millions': 2010,
#  'isis': 2009,
#  'sent': 2007,
#  'george': 2003,
#  'crime': 2002,
#  'issues': 2002,
#  '10': 2001,
#  'bernie': 1998,
#  'wednesday': 1995,
#  'college': 1995,
#  'possible': 1994,
#  'terrorist': 1994,
#  'politics': 1993,
#  'chief': 1989,
#  'held': 1982,
#  'especially': 1981,
#  'center': 1981,
#  'feel': 1978,
#  'cia': 1977,
#  'received': 1977,
#  'jobs': 1975,
#  'list': 1975,
#  'refugees': 1973,
#  'foundation': 1969,
#  'effort': 1969,
#  'further': 1965,
#  'staff': 1965,
#  'organization': 1958,
#  'mean': 1954,
#  'enforcement': 1953,
#  'apparently': 1946,
#  'continued': 1925,
#  'supreme': 1922,
#  'current': 1920,
#  '20': 1919,
#  'breitbart': 1908,
#  'allowed': 1903,
#  'leaders': 1896,
#  'announced': 1896,
#  'process': 1889,
#  'middle': 1888,
#  'defense': 1884,
#  'immigrants': 1880,
#  'month': 1880,
#  'mainstream': 1875,
#  'james': 1870,
#  'letter': 1870,
#  'friends': 1863,
#  'else': 1859,
#  'father': 1853,
#  'either': 1852,
#  'together': 1852,
#  'voting': 1851,
#  'governor': 1846,
#  'looking': 1841,
#  'front': 1838,
#  'iran': 1836,
#  'close': 1835,
#  'personal': 1835,
#  'below': 1835,
#  'agency': 1835,
#  'article': 1832,
#  'added': 1821,
#  'release': 1820,
#  'nuclear': 1818,
#  'exactly': 1812,
#  'child': 1810,
#  'cannot': 1805,
#  'reality': 1804,
#  'wife': 1801,
#  'try': 1800,
#  'putin': 1797,
#  'paid': 1796,
#  'rep': 1795,
#  'civil': 1794,
#  'conservatives': 1790,
#  'movement': 1788,
#  'elected': 1780,
#  'five': 1779,
#  'based': 1777,
#  'network': 1776,
#  'side': 1773,
#  'absolutely': 1770,
#  'questions': 1768,
#  'islamic': 1768,
#  'goes': 1765,
#  'posted': 1761,
#  'o': 1760,
#  'start': 1760,
#  'flag': 1759,
#  'started': 1758,
#  'hope': 1756,
#  'water': 1753,
#  'involved': 1750,
#  'candidates': 1748,
#  'latest': 1747,
#  'protesters': 1742,
#  'turned': 1740,
#  '2': 1740,
#  'climate': 1738,
#  'documents': 1730,
#  'whole': 1727,
#  'secret': 1724,
#  '3': 1716,
#  'majority': 1714,
#  'screen': 1713,
#  'ted': 1711,
#  'role': 1706,
#  'appears': 1700,
#  'turn': 1699,
#  'laws': 1697,
#  'outside': 1696,
#  '(realdonaldtrump)': 1693,
#  'bring': 1691,
#  'son': 1690,
#  'telling': 1684,
#  'thousands': 1684,
#  'completely': 1683,
#  'earlier': 1679,
#  'lead': 1678,
#  'fire': 1676,
#  'future': 1674,
#  'heard': 1673,
#  'often': 1671,
#  'threat': 1668,
#  '4': 1658,
#  'protect': 1654,
#  'accused': 1653,
#  'reporter': 1651,
#  'position': 1649,
#  'crowd': 1647,
#  'knows': 1643,
#  'alleged': 1643,
#  'failed': 1631,
#  'violent': 1629,
#  'knew': 1622,
#  'terror': 1622,
#  'freedom': 1618,
#  'weeks': 1615,
#  'dollars': 1610,
#  'speak': 1606,
#  'page': 1605,
#  'example': 1601,
#  'book': 1598,
#  'nearly': 1598,
#  'serious': 1597,
#  'hands': 1593,
#  'global': 1593,
#  'mccain': 1590,
#  'speaking': 1588,
#  'ask': 1586,
#  'worked': 1584,
#  'presidency': 1583,
#  'district': 1583,
#  'understand': 1576,
#  'saw': 1575,
#  'votes': 1574,
#  'early': 1568,
#  'joe': 1567,
#  'whose': 1567,
#  '2014': 1567,
#  '5': 1564,
#  'record': 1562,
#  'leave': 1560,
#  'hours': 1559,
#  'student': 1557,
#  'spent': 1554,
#  'billion': 1554,
#  'saturday': 1551,
#  'due': 1551,
#  'god': 1551,
#  'access': 1550,
#  'protest': 1545,
#  'certainly': 1545,
#  'fired': 1544,
#  'air': 1542,
#  'conference': 1541,
#  'asking': 1540,
#  'mass': 1535,
#  'terrorists': 1534,
#  'florida': 1531,
#  'syrian': 1531,
#  'maybe': 1530,
#  'families': 1530,
#  'david': 1529,
#  '30': 1527,
#  'policies': 1526,
#  'calls': 1522,
#  '8': 1522,
#  'gets': 1518,
#  'couldn': 1514,
#  'actions': 1513,
#  'finally': 1510,
#  'radical': 1510,
#  'moment': 1506,
#  'mark': 1504,
#  'mother': 1503,
#  '15': 1501,
#  'michael': 1500,
#  'hit': 1500,
#  'voted': 1496,
#  'weapons': 1494,
#  'incident': 1493,
#  'attempt': 1490,
#  'allow': 1489,
#  'south': 1488,
#  'radio': 1488,
#  'became': 1486,
#  'california': 1483,
#  'dnc': 1478,
#  'ban': 1476,
#  'wouldn': 1475,
#  'account': 1475,
#  'capture': 1474,
#  'hand': 1474,
#  'planned': 1473,
#  'answer': 1470,
#  'tweeted': 1467,
#  'religious': 1465,
#  'voter': 1465,
#  'sources': 1464,
#  '1': 1464,
#  'single': 1462,
#  'giving': 1462,
#  'living': 1460,
#  'arrested': 1459,
#  'false': 1458,
#  'spoke': 1455,
#  'economic': 1455,
#  'photo': 1453,
#  'led': 1452,
#  'victims': 1448,
#  'primary': 1442,
#  'financial': 1441,
#  '2012': 1441,
#  'situation': 1438,
#  'hear': 1437,
#  'kids': 1436,
#  'strong': 1433,
#  'remember': 1431,
#  'mike': 1430,
#  'inside': 1429,
#  'building': 1427,
#  'mayor': 1421,
#  'church': 1417,
#  'worse': 1414,
#  'longer': 1410,
#  'iraq': 1409,
#  'large': 1406,
#  'thinks': 1405,
#  'events': 1405,
#  'revealed': 1402,
#  'dangerous': 1398,
#  'senior': 1397,
#  'efforts': 1395,
#  '12': 1394,
#  'small': 1391,
#  'view': 1387,
#  'dc': 1386,
#  'racism': 1384,
#  'immediately': 1384,
#  'yes': 1384,
#  'hold': 1384,
#  'nations': 1378,
#  'al': 1375,
#  'points': 1375,
#  'class': 1374,
#  'parents': 1371,
#  'fear': 1369,
#  'rubio': 1369,
#  'agenda': 1368,
#  'responded': 1368,
#  'brought': 1366,
#  'seem': 1364,
#  'agents': 1363,
#  'regarding': 1360,
#  'israel': 1359,
#  'assault': 1359,
#  'website': 1354,
#  'forced': 1354,
#  'congressional': 1353,
#  'union': 1352,
#  'lies': 1350,
#  'result': 1350,
#  'popular': 1344,
#  'moore': 1343,
#  'rest': 1342,
#  'created': 1340,
#  'behavior': 1337,
#  'sean': 1335,
#  'appeared': 1335,
#  'word': 1332,
#  'short': 1332,
#  'attention': 1331,
#  'guns': 1330,
#  'happen': 1327,
#  'cause': 1324,
#  'west': 1324,
#  'facts': 1323,
#  'employees': 1323,
#  'rich': 1321,
#  '11': 1318,
#  'hollywood': 1318,
#  'records': 1316,
#  'workers': 1316,
#  'terrorism': 1314,
#  'quite': 1311,
#  'currently': 1310,
#  'crisis': 1309,
#  'poll': 1308,
#  'amendment': 1307,
#  'safe': 1305,
#  'society': 1305,
#  'total': 1301,
#  'lie': 1296,
#  'late': 1292,
#  'husband': 1292,
#  'perhaps': 1291,
#  '7': 1290,
#  'sen': 1289,
#  'mexico': 1289,
#  'provide': 1288,
#  'confirmed': 1287,
#  'forward': 1286,
#  'data': 1286,
#  'aren': 1285,
#  'huge': 1285,
#  'agencies': 1283,
#  'companies': 1282,
#  'continues': 1278,
#  'charges': 1274,
#  'near': 1273,
#  'looks': 1272,
#  'obamacare': 1271,
#  'published': 1270,
#  'met': 1270,
#  'plans': 1268,
#  'reporters': 1265,
#  'six': 1263,
#  'phone': 1263,
#  'literally': 1262,
#  'council': 1261,
#  'numbers': 1260,
#  'showed': 1259,
#  'sessions': 1256,
#  'mind': 1255,
#  'flynn': 1255,
#  'food': 1251,
#  'stated': 1250,
#  'christian': 1249,
#  'play': 1248,
#  'gay': 1248,
#  'star': 1246,
#  'friend': 1246,
#  'refused': 1244,
#  'visit': 1243,
#  'conspiracy': 1242,
#  'education': 1237,
#  'elections': 1237,
#  'dead': 1236,
#  'respect': 1236,
#  'upon': 1233,
#  'level': 1232,
#  'include': 1231,
#  'comment': 1231,
#  '9': 1229,
#  'board': 1229,
#  'services': 1224,
#  'funding': 1222,
#  '2017realdonaldtrump': 1221,
#  'fraud': 1220,
#  'massive': 1219,
#  'area': 1219,
#  'share': 1218,
#  'repeatedly': 1218,
#  '24': 1216,
#  'gone': 1216,
#  'robert': 1211,
#  'king': 1211,
#  'multiple': 1210,
#  'east': 1209,
#  'poor': 1205,
#  'cost': 1203,
#  'cut': 1202,
#  'tv': 1200,
#  'propaganda': 1194,
#  'believes': 1194,
#  'remarks': 1194,
#  'half': 1191,
#  'kelly': 1189,
#  'interest': 1188,
#  'supposed': 1186,
#  'sense': 1186,
#  'daughter': 1184,
#  'standing': 1184,
#  'cases': 1182,
#  'leading': 1182,
#  'town': 1180,
#  'lying': 1179,
#  'rules': 1179,
#  'sign': 1178,
#  'decades': 1178,
#  'soon': 1176,
#  'itself': 1175,
#  'cover': 1174,
#  'constitution': 1172,
#  'san': 1171,
#  '21wire': 1170,
#  'research': 1168,
#  'responsible': 1168,
#  'hannity': 1168,
#  '18': 1167,
#  'address': 1164,
#  'chris': 1163,
#  'included': 1163,
#  'supporter': 1163,
#  'convention': 1163,
#  'chicago': 1163,
#  'featured': 1160,
#  '14': 1158,
#  '2013': 1156,
#  'carolina': 1155,
#  'individuals': 1152,
#  'certain': 1151,
#  'internet': 1150,
#  'abortion': 1150,
#  'scandal': 1146,
#  'described': 1146,
#  ...}
