# %%
import pandas as pd

# %%
df = pd.read_csv ('dataset/Fake.csv')
fileFake = df['text'].to_list()
a = list(map(lambda x: x.lower(),fileFake[1].split(' ')))

# %%
b={i:0 for i in a}
for i in a:
    b[i]+=1

# %%
#Сортировка
b={k: v for k, v in sorted(b.items(), key=lambda item: item[1],reverse=True)}
b
# Out:
# {'': 20,
#  'the': 17,
#  'to': 17,
#  'december': 14,
#  '30,': 14,
#  'of': 9,
#  'a': 9,
#  'i': 9,
#  'and': 8,
#  'by': 8,
#  'your': 8,
#  'in': 7,
#  'with': 7,
#  'them': 7,
#  'it': 6,
#  'that': 5,
#  's': 5,
#  'fake': 5,
#  't': 5,
#  'you': 5,
#  'was': 4,
#  'clarke,': 4,
#  'search': 4,
#  'warrant': 4,
#  'news': 4,
#  'lib': 4,
#  'media': 4,
#  'their': 4,
#  'people': 4,
#  'on': 3,
#  'david': 3,
#  'who': 3,
#  'for': 3,
#  'his': 3,
#  'clarke': 3,
#  'police': 3,
#  'been': 3,
#  'is': 3,
#  'smear': 3,
#  'me,': 3,
#  'continue': 3,
#  'eye': 3,
#  'they': 3,
#  'better': 3,
#  'than': 3,
#  'at': 3,
#  'just': 3,
#  'former': 2,
#  'milwaukee': 2,
#  'sheriff': 2,
#  'has': 2,
#  'email': 2,
#  'he': 2,
#  'stop': 2,
#  'black': 2,
#  'after': 2,
#  'am': 2,
#  'unintimidated': 2,
#  'attempts': 2,
#  'discredit': 2,
#  'me': 2,
#  'reports': 2,
#  'designed': 2,
#  'silence': 2,
#  'will': 2,
#  'poke': 2,
#  'sharp': 2,
#  'stick': 2,
#  'bitch': 2,
#  'slap': 2,
#  'these': 2,
#  'scum': 2,
#  'bags': 2,
#  'til': 2,
#  'get': 2,
#  'it.': 2,
#  'have': 2,
#  'attacked': 2,
#  '#maga': 2,
#  'a.': 2,
#  'jr.': 2,
#  '(@sheriffclarke)': 2,
#  'when': 2,
#  'lying': 2,
#  'up': 2,
#  'taste': 2,
#  'own': 2,
#  'internet': 2,
#  'called': 2,
#  'not': 2,
#  '2017you': 2,
#  'chris': 2,
#  '2017is': 2,
#  'this': 2,
#  'think': 2,
#  '2017are': 2,
#  'fingers': 2,
#  'died': 2,
#  're': 2,
#  'can': 2,
#  'be': 2,
#  'we': 2,
#  'friday,': 1,
#  'revealed': 1,
#  'being': 1,
#  'considered': 1,
#  'homeland': 1,
#  'security': 1,
#  'secretary': 1,
#  'donald': 1,
#  'trump': 1,
#  'administration,': 1,
#  'an': 1,
#  'scandal': 1,
#  'own.in': 1,
#  'january,': 1,
#  'there': 1,
#  'brief': 1,
#  'run-in': 1,
#  'plane': 1,
#  'between': 1,
#  'fellow': 1,
#  'passenger': 1,
#  'dan': 1,
#  'black,': 1,
#  'later': 1,
#  'had': 1,
#  'detained': 1,
#  'no': 1,
#  'reason': 1,
#  'whatsoever,': 1,
#  'except': 1,
#  'maybe': 1,
#  'feelings': 1,
#  'were': 1,
#  'hurt.': 1,
#  'messaged': 1,
#  'deplaned,': 1,
#  'now,': 1,
#  'executed': 1,
#  'fbi': 1,
#  'see': 1,
#  'exchanges.clarke': 1,
#  'calling': 1,
#  'even': 1,
#  'though': 1,
#  'copies': 1,
#  'are': 1,
#  'internet.': 1,
#  'tweeted.': 1,
#  'me.': 1,
#  'pic.twitter.com/xtzw5pdu2b': 1,
#  '2017he': 1,
#  'didn': 1,
#  'there.breaking': 1,
#  'news!': 1,
#  'makes': 1,
#  'antidote': 1,
#  'go': 1,
#  'right': 1,
#  'them.': 1,
#  'punch': 1,
#  'nose': 1,
#  '&': 1,
#  'make': 1,
#  'blood.': 1,
#  'nothing': 1,
#  'gets': 1,
#  'bully': 1,
#  'like': 1,
#  'attention': 1,
#  'give': 1,
#  'blood': 1,
#  '#neverbackdown': 1,
#  'pic.twitter.com/t2ny2pshcr': 1,
#  '2017the': 1,
#  'him': 1,
#  'out.this': 1,
#  'local': 1,
#  'newspaper': 1,
#  'isn': 1,
#  'fake,': 1,
#  'because': 1,
#  'chose': 1,
#  'file': 1,
#  'charges': 1,
#  'time': 1,
#  'doesn': 1,
#  'mean': 1,
#  'won': 1,
#  't!': 1,
#  'especially': 1,
#  'if': 1,
#  'lie.': 1,
#  'months': 1,
#  'decision': 1,
#  'charge': 1,
#  'filed': 1,
#  'https://t.co/zcbyc4wp5b': 1,
#  'keithleblanc': 1,
#  '(@keithleblanc63)': 1,
#  '2017i': 1,
#  'hope': 1,
#  'rest': 1,
#  'village': 1,
#  'aren': 1,
#  'implicated.': 1,
#  'kirk': 1,
#  'ketchum': 1,
#  '(@kirkketchum)': 1,
#  '2017slaw,': 1,
#  'baked': 1,
#  'potatoes,': 1,
#  'or': 1,
#  'french': 1,
#  'fries?': 1,
#  'pic.twitter.com/fwfxszupxy': 1,
#  'alt-': 1,
#  'immigration': 1,
#  '(@alt_uscis)': 1,
#  '2017pic.twitter.com/ymsobljfxu': 1,
#  'pendulum': 1,
#  'swinger': 1,
#  '(@pendulumswngr)': 1,
#  'friends': 1,
#  'stand': 1,
#  'someone': 1,
#  'made': 1,
#  'fun': 1,
#  'hat': 1,
#  'jackson': 1,
#  '(@chriscjackson)': 1,
#  'masterful': 1,
#  'pshop': 1,
#  'hat,': 1,
#  'which': 1,
#  'seem': 1,
#  'never': 1,
#  'tire': 1,
#  'of.': 1,
#  'steely': 1,
#  'resolve': 1,
#  'one': 1,
#  'visible': 1,
#  'pic.twitter.com/dwr5k8zezv': 1,
#  'mohney': 1,
#  '(@chrismohney)': 1,
#  'indicating': 1,
#  'how': 1,
#  'many': 1,
#  'jail?': 1,
#  'few': 1,
#  'short,': 1,
#  'dipshit': 1,
#  'ike': 1,
#  'barinholtz': 1,
#  '(@ikebarinholtz)': 1,
#  '2017rofl.': 1,
#  'tough': 1,
#  'guy': 1,
#  'flair.': 1,
#  'pic.twitter.com/ulcfddhkdy': 1,
#  'kellmecrazy': 1,
#  '(@kel_moonface)': 1,
#  'so': 1,
#  'edgy,': 1,
#  'buddy.': 1,
#  'mrs.': 1,
#  'smh': 1,
#  '(@mrssmh2)': 1,
#  'break': 1,
#  'over': 1,
#  'applebees?': 1,
#  'aaron': 1,
#  '(@feltrrr2)': 1,
#  'trying': 1,
#  'earn': 1,
#  'still': 1,
#  'relevant': 1,
#  'badge?': 1,
#  'circusrebel': 1,
#  '(@circusdrew)': 1,
#  '2017make': 1,
#  'sure': 1,
#  'hydrate,': 1,
#  'drink': 1,
#  'lots': 1,
#  'water.': 1,
#  'rumored': 1,
#  'prisoners': 1,
#  'denied': 1,
#  'water': 1,
#  'prison': 1,
#  'officials.': 1,
#  'robert': 1,
#  'klinc': 1,
#  '(@robertklinc1)': 1,
#  '2017terrill': 1,
#  'thomas,': 1,
#  '38-year-old': 1,
#  'man': 1,
#  'thirst': 1,
#  'county': 1,
#  'jail': 1,
#  'cell': 1,
#  'april,': 1,
#  'victim': 1,
#  'homicide.': 1,
#  'thought': 1,
#  'should': 1,
#  'point': 1,
#  'out.': 1,
#  'repeated': 1,
#  'enough.photo': 1,
#  'spencer': 1,
#  'platt/getty': 1,
#  'images.': 1}
